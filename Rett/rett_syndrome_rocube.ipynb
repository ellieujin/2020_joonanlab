# %% [markdown]
# #### 1. import data

# %%
import hail as hl
rett = hl.import_vcf('../../inputs/191102-rett-wgs.vep_tx_191206.vcf.bgz', reference_genome='GRCh38')
# Out:
# Initializing Spark and Hail with default parameters...
# Running on Apache Spark version 2.4.1
# SparkUI available at http://192.168.0.5:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.28-61941242c15d
# LOGGING: writing to /Users/lizzychoi/rett_syndrome/scripts/rett_syndrome/hail-20200110-1007-0.2.28-61941242c15d.log

# %%
#print(rett.count())

# %% [markdown]
# ---

# %% [markdown]
# #### 2. variant filtering
# > - `filter == PASS`인 variant만 남기기
# > - multi allelic 확인 및 제외
# > - gnomAD AC==0인(한번도 발견된 적 없는 variant)만 남기기
# > - chrM, chrX, chrY 제외
# > - LCR(low complexity region) 제외

# %% [markdown]
# #### (1) `filter == PASS`인 variant만 남기기

# %%
rett = rett.filter_rows(hl.len(rett.filters) == 0)

# %%
#print(rett.count())

# %% [markdown]
# #### (2) multi allelic 확인 및 제외

# %%
import gzip

multi_allelic = 0

with gzip.open('../../inputs/191102-rett-wgs.vep_tx_191206.vcf.bgz', 'rt') as f:
    for l in f:
        if l[0:1] != '#':
            if ',' in l.strip('\n').split('\t')[4]:
                multi_allelic += 1

print(multi_allelic)
# Out:
# 1111205

# %%
## Split multiallelic variants
rett = hl.split_multi(rett)

## Drop multiallelic variants
rett = rett.filter_rows(rett.was_split == False)

#rett.count()

# %% [markdown]
# #### (3) gnomAD AC==0인(한번도 발견된 적 없는 variant)만 남기기

# %% [markdown]
# ##### (CSQ_gnomADg_AF활용)
# - `gnomADg_AF`의 'g'는 genome(cf. gnomAD_AF는 ExAC)
# - `gnomADg_AF` 정보가 없는 variant만 남기기(즉,  ["", "", ""] 경우만 남김) => **330122**
#  - ["0","0","0","0"]인 경우도 포함 => **332777**

# %%
import gzip
with gzip.open('../../inputs/191102-rett-wgs.vep_tx_191206.vcf.bgz', 'rt') as f:
    for l in f:
        if 'ID=CSQ' in l:
            temp = l.strip('\n').split('|')
            break

temp[0] = 'Allele';temp[70] = 'gnomADg_AF'

#print(temp)
print(temp.index('gnomADg_AF'))
# Out:
# 70

# %%
#temp
# Out:
# ['Allele',
#  'Consequence',
#  'IMPACT',
#  'SYMBOL',
#  'Gene',
#  'Feature_type',
#  'Feature',
#  'BIOTYPE',
#  'EXON',
#  'INTRON',
#  'HGVSc',
#  'HGVSp',
#  'cDNA_position',
#  'CDS_position',
#  'Protein_position',
#  'Amino_acids',
#  'Codons',
#  'Existing_variation',
#  'DISTANCE',
#  'STRAND',
#  'FLAGS',
#  'VARIANT_CLASS',
#  'SYMBOL_SOURCE',
#  'HGNC_ID',
#  'CANONICAL',
#  'MANE',
#  'TSL',
#  'APPRIS',
#  'CCDS',
#  'ENSP',
#  'SWISSPROT',
#  'TREMBL',
#  'UNIPARC',
#  'SOURCE',
#  'GENE_PHENO',
#  'NEAREST',
#  'SIFT',
#  'PolyPhen',
#  'DOMAINS',
#  'miRNA',
#  'HGVS_OFFSET',
#  'AF',
#  'AFR_AF',
#  'AMR_AF',
#  'EAS_AF',
#  'EUR_AF',
#  'SAS_AF',
#  'AA_AF',
#  'EA_AF',
#  'gnomAD_AF',
#  'gnomAD_AFR_AF',
#  'gnomAD_AMR_AF',
#  'gnomAD_ASJ_AF',
#  'gnomAD_EAS_AF',
#  'gnomAD_FIN_AF',
#  'gnomAD_NFE_AF',
#  'gnomAD_OTH_AF',
#  'gnomAD_SAS_AF',
#  'MAX_AF',
#  'MAX_AF_POPS',
#  'CLIN_SIG',
#  'SOMATIC',
#  'PHENO',
#  'PUBMED',
#  'MOTIF_NAME',
#  'MOTIF_POS',
#  'HIGH_INF_POS',
#  'MOTIF_SCORE_CHANGE',
#  'MPC',
#  'gnomADg',
#  'gnomADg_AF']

# %%
rett = rett.annotate_rows(csq = rett.info.CSQ)
rett = rett.transmute_rows(csq_gnomADg_AF = rett.csq.map(lambda x: x.split('\|')[70]))

# %% [markdown]
# ---

# %%
## transcipt이 여러개여도, 같은 variant에 한해서는 gnomADg_AF값은 같다.
#rett.filter_rows(hl.len(hl.set(rett.csq_gnomADg_AF))!=1).count_rows()

# %%
l = hl.array(['0',''])
rett = rett.filter_rows(rett.csq_gnomADg_AF.all(lambda x: l.contains(x)))

# %%
#rett.count_rows()
# Out:
# 332777

# %% [markdown]
# #### (4)chrM, chrX, chrY 제외

# %%
rett = rett.filter_rows(rett.locus.in_autosome())

# %% [markdown]
# #### (5) lcr(low complexity region)제외

# %%
lcr_bed = hl.import_bed('../../../Resources/lcr/LCR-hs38.bed', reference_genome = 'GRCh38')
# Out:
# 2019-12-24 11:15:12 Hail: INFO: Reading table with no type imputation
#   Loading column 'f0' as type 'str' (user-specified)
#   Loading column 'f1' as type 'int32' (user-specified)
#   Loading column 'f2' as type 'int32' (user-specified)

# %%
lcr_bed.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'interval': interval<locus<GRCh38>>
# ----------------------------------------
# Key: ['interval']
# ----------------------------------------

# %%
rett = rett.filter_rows(~hl.is_defined(lcr_bed[rett.locus]))

# %%
#rett.count_rows()

# %% [markdown]
# ---

# %% [markdown]
# #### 3. rare variants만 남기기 (rare variants : AC==2인 변이들로 가정) + hom 제거하고 het만

# %%
rett_rare = rett.filter_rows(rett.info.AC[0] == 2)
#print(rett_rare.count_rows())

# %%
#위의 cell과 같은 결과

#rett = hl.variant_qc(rett)
#rett_rare_s = rett.filter_rows((rett.variant_qc.AC[0]==2)|(rett.variant_qc.AC[1]==2))
#print(rett_rare.count_rows())

# %%
## drop vairants(homozygous)
rett_rare = hl.variant_qc(rett_rare)
rett_rare_het = rett_rare.filter_rows(rett_rare.variant_qc.n_het==2)

#print(rett_rare_het.count_rows())

# %%
rett_rare_het.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         AC: array<int32>,
#         AF: array<float64>,
#         AN: int32,
#         BaseQRankSum: float64,
#         DB: bool,
#         DP: int32,
#         DS: bool,
#         END: int32,
#         ExcessHet: float64,
#         FS: float64,
#         InbreedingCoeff: float64,
#         MLEAC: array<int32>,
#         MLEAF: array<float64>,
#         MQ: float64,
#         MQRankSum: float64,
#         NEGATIVE_TRAIN_SITE: bool,
#         POSITIVE_TRAIN_SITE: bool,
#         QD: float64,
#         RAW_MQandDP: array<int32>,
#         ReadPosRankSum: float64,
#         SOR: float64,
#         VQSLOD: float64,
#         culprit: str,
#         CSQ: array<str>,
#         gnomADg: array<str>,
#         gnomADg_AF: array<str>
#     }
#     'a_index': int32
#     'was_split': bool
#     'old_locus': locus<GRCh38>
#     'old_alleles': array<str>
#     'csq_gnomADg_AF': array<str>
#     'variant_qc': struct {
#         dp_stats: struct {
#             mean: float64,
#             stdev: float64,
#             min: float64,
#             max: float64
#         },
#         gq_stats: struct {
#             mean: float64,
#             stdev: float64,
#             min: float64,
#             max: float64
#         },
#         AC: array<int32>,
#         AF: array<float64>,
#         AN: int32,
#         homozygote_count: array<int32>,
#         call_rate: float64,
#         n_called: int64,
#         n_not_called: int64,
#         n_filtered: int64,
#         n_het: int64,
#         n_non_ref: int64,
#         het_freq_hwe: float64,
#         p_value_hwe: float64
#     }
# ----------------------------------------
# Entry fields:
#     'AD': array<int32>
#     'DP': int32
#     'GQ': int32
#     'GT': call
#     'MIN_DP': int32
#     'PGT': call
#     'PID': str
#     'PL': array<int32>
#     'PS': int32
#     'RGQ': int32
#     'SB': array<int32>
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# ----------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# #### 5. Positive, Negative set 만들기
# - Index : **variant, Role, Fam**
# - features
#     - **va_QUAL, va_AN, va_BaseQRankSum,va_DP,va_ExcessHet, va_FS, va_InbreedingCoeff, va_MQ,va_MQRankSum, va_QD, va_ReadPosRankSum, va_SOR, va_VQSLOD, va_GQM**
#     - **g_GQ, g_AD**(--> `rocube.py`에서 **g_DP**, **g_AB**계산 된다)
# - label : **TP**

# %%
MT_PN = rett_rare_het.filter_entries(rett_rare_het.GT.is_het())
Table_PN = MT_PN.entries()
Table_PN = Table_PN.annotate(va_AN = Table_PN.info.AN,
                             va_BaseQRankSum = Table_PN.info.BaseQRankSum,
                             va_DP = Table_PN.info.DP,
                             va_ExcessHet = Table_PN.info.ExcessHet,
                             va_FS = Table_PN.info.FS,
                             va_InbreedingCoeff = Table_PN.info.InbreedingCoeff,
                             va_MQ = Table_PN.info.MQ,
                             va_MQRankSum = Table_PN.info.MQRankSum,
                             va_QD = Table_PN.info.QD,
                             va_ReadPosRankSum = Table_PN.info.ReadPosRankSum,
                             va_SOR = Table_PN.info.SOR,
                             va_VQSLOD = Table_PN.info.VQSLOD,
                             va_GQM =Table_PN.variant_qc.gq_stats.mean)
# Out:
# 2019-12-24 11:16:19 Hail: WARN: entries(): Resulting entries table is sorted by '(row_key, col_key)'.
#     To preserve row-major matrix table order, first unkey columns with 'key_cols_by()'

# %%
#### Index and Features
## variant
Table_PN_i = Table_PN.annotate(v1 = hl.tuple([Table_PN.locus.contig.replace("chr", ""),hl.str(Table_PN.locus.position)]),
                               v2 = hl.tuple([Table_PN.alleles[0],Table_PN.alleles[1]]))
Table_PN_i = Table_PN_i.transmute(variant = hl.delimit(hl.array([Table_PN_i.v1[0], 
                                                              Table_PN_i.v1[1], 
                                                              Table_PN_i.v2[0], 
                                                              Table_PN_i.v2[1]]), ":"))

## Role, Fam, TP
Table_PN_i = Table_PN_i.annotate(Role = Table_PN_i.s.split('_')[1],
                                 Fam = Table_PN_i.s.split('_')[0],
                                 TP = 0)

## Role(category 1,2,3 --> p, mo, fa)
## qual, GQ, AD
Table_PN_i = Table_PN_i.transmute(Role = hl.cond(Table_PN_i.Role=='1', 'p', hl.cond(Table_PN_i.Role=='2', 'mo','fa')),
                                 va_QUAL = Table_PN_i.qual,
                                 g_GQ = Table_PN_i.GQ,
                                 g_AD = Table_PN_i.AD)

## Updating fields (select columns)
Table_PN_complete = Table_PN_i.select(Table_PN_i.variant, Table_PN_i.Role, Table_PN_i.Fam, Table_PN_i.TP,
                                      Table_PN_i.va_QUAL,Table_PN_i.va_AN,Table_PN_i.va_BaseQRankSum,
                                      Table_PN_i.va_DP,Table_PN_i.va_ExcessHet,Table_PN_i.va_FS,
                                      Table_PN_i.va_InbreedingCoeff,
                                      Table_PN_i.va_MQ,Table_PN_i.va_MQRankSum,
                                      Table_PN_i.va_QD,Table_PN_i.va_ReadPosRankSum,
                                      Table_PN_i.va_SOR,Table_PN_i.va_VQSLOD,Table_PN_i.va_GQM,
                                      Table_PN_i.g_GQ,Table_PN_i.g_AD)

## key drop --> key : variant
Table_PN_complete = Table_PN_complete.key_by(Table_PN_complete.variant)

## Updating fields (drop columns)
Table_PN_complete = Table_PN_complete.drop(Table_PN_complete.locus, Table_PN_complete.alleles, Table_PN_complete.s)

# %%
#### Label
## positive set (TP ==1), negative set (TP ==2)
tp = Table_PN_complete.group_by(Table_PN_complete.variant).aggregate(i = hl.agg.collect_as_set(Table_PN_complete.Fam).length())
Table_PN_complete = Table_PN_complete.join(tp, 'left')
Table_PN_complete = Table_PN_complete.transmute(TP = Table_PN_complete.i)

## positive set(TP==1) 중 proband를 포함하지 않는 variant 제외(즉, 엄마아빠가 variant 하나씩 가지는 경우)
## negative set(TP==2) 중 proband를 포함하지 않는 variant 제외(즉, 서로 다른 가족의 부모세대에서 variant가 하나씩 발견된 경우)
p = Table_PN_complete.group_by(Table_PN_complete.variant).aggregate(j = hl.agg.collect_as_set(Table_PN_complete.Role).contains('p'))
Table_PN_complete = Table_PN_complete.join(p, 'left')
Table_PN_complete = Table_PN_complete.filter(Table_PN_complete.j == True)
Table_PN_complete = Table_PN_complete.drop(Table_PN_complete.j)

# %%
## negatibe set(TP==2) 중 proband만 있는 경우 제외
n = Table_PN_complete.group_by(Table_PN_complete.variant).aggregate(k = hl.agg.collect_as_set(Table_PN_complete.Role).length())
Table_PN_complete = Table_PN_complete.join(n, 'left')
Table_PN_complete = Table_PN_complete.filter(~((Table_PN_complete.TP==2)&(Table_PN_complete.k==1)))
Table_PN_complete = Table_PN_complete.drop(Table_PN_complete.k)

# %%
#Table_PN_complete.export('../../output/ROCube_trainMat_rett.tsv')

# %%
#Table_PN_complete.count()

# %%
Table_PN_complete.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'variant': str
#     'Role': str
#     'Fam': str
#     'TP': int32
#     'va_QUAL': float64
#     'va_AN': int32
#     'va_BaseQRankSum': float64
#     'va_DP': int32
#     'va_ExcessHet': float64
#     'va_FS': float64
#     'va_InbreedingCoeff': float64
#     'va_MQ': float64
#     'va_MQRankSum': float64
#     'va_QD': float64
#     'va_ReadPosRankSum': float64
#     'va_SOR': float64
#     'va_VQSLOD': float64
#     'va_GQM': float64
#     'g_GQ': int32
#     'g_AD': array<int32>
# ----------------------------------------
# Key: ['variant']
# ----------------------------------------

# %% [markdown]
# ---

# %% [markdown]
# #### 6. (Positive, Negative set) SNP, Indel 나누기

# %%
Table_PN_c_hl = Table_PN_complete

# %%
Table_PN_c_hl = Table_PN_c_hl.annotate(snp = hl.is_snp(Table_PN_c_hl.variant.split(':')[2], Table_PN_c_hl.variant.split(':')[3]),
                                       indel = hl.is_indel(Table_PN_c_hl.variant.split(':')[2], Table_PN_c_hl.variant.split(':')[3]))

Table_PN_SNP = Table_PN_c_hl.filter(Table_PN_c_hl.snp == True)
Table_PN_Indel = Table_PN_c_hl.filter(Table_PN_c_hl.indel == True)

Table_PN_SNP = Table_PN_SNP.drop('snp', 'indel')
Table_PN_Indel = Table_PN_Indel.drop('snp', 'indel')

# %%
## export files
Table_PN_SNP.export("../../Tables/ROCube_trainMat_rett_SNP.tsv")
Table_PN_Indel.export("../../Tables/ROCube_trainMat_rett_Indel.tsv")
# Out:
# 2019-12-23 13:12:55 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:13:12 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:13:58 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:15:19 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:15:35 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:15:52 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:16:26 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:17:39 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:17:55 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:18:12 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:18:46 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:19:56 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:20:12 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:20:28 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:21:03 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:22:15 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:22:31 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:22:47 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:23:22 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:24:30 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:24:46 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:25:02 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:25:37 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:26:49 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:27:05 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:27:21 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:27:55 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:29:05 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:29:21 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:29:37 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:30:11 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:31:23 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:36:32 Hail: INFO: merging 142 files totalling 39.7M...
# 2019-12-23 13:36:32 Hail: INFO: while writing:
#     ../../outputs/ROCube_trainMat_rett_SNP.tsv
#   merge time: 97.516ms
# 2019-12-23 13:36:49 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:37:06 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:37:52 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:39:11 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:39:27 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:39:43 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:40:18 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:41:30 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:41:46 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:42:02 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:42:36 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:43:45 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:44:01 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:44:17 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:44:52 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:46:04 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:46:20 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:46:36 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:47:10 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:48:18 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:48:34 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:48:51 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:49:25 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:50:37 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:50:53 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:51:09 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:51:43 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:52:52 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 13:53:08 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:53:24 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:53:59 Hail: INFO: Coerced sorted dataset
# 2019-12-23 13:55:11 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2019-12-23 14:00:22 Hail: INFO: merging 142 files totalling 3.9M...
# 2019-12-23 14:00:22 Hail: INFO: while writing:
#     ../../outputs/ROCube_trainMat_rett_Indel.tsv
#   merge time: 59.372ms

# %% [markdown]
# ---

# %% [markdown]
# #### 7. (Positive, Negative set) quality distribution

# %% [markdown]
# (training set 정리)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
df_SNP = pd.read_csv("../../Tables/ROCube_trainMat_rett_SNP.tsv", delimiter='\t')
df_Indel = pd.read_csv("../../Tables/ROCube_trainMat_rett_Indel.tsv", delimiter='\t')                     

df_SNP['TP'] = df_SNP['TP'].astype('category')
df_SNP['TP'].cat.categories = ['Positive','Negative']
df_Indel['TP'] = df_Indel['TP'].astype('category')
df_Indel['TP'].cat.categories = ['Positive','Negative']

# %%
## g_DP 추가
df2_SNP = df_SNP.g_AD.str.replace('[','').str.replace(']','').str.split(',', expand=True).astype(int)
df2_Indel = df_Indel.g_AD.str.replace('[','').str.replace(']','').str.split(',', expand=True).astype(int)
df_SNP['g_DP'] = df2_SNP[0] + df2_SNP[1]
df_Indel['g_DP'] = df2_Indel[0] + df2_Indel[1]

# %%
## g_AB 추가
df_SNP['g_AB2'] = df2_SNP[1] / df_SNP['g_DP'].astype(float)
df_SNP['g_AB'] = df_SNP.apply(lambda row: 1 - row['g_AB2'] if row['g_AB2'] >= 0.5 else row['g_AB2'], axis=1)

df_Indel['g_AB2'] = df2_Indel[1] / df_Indel['g_DP'].astype(float)
df_Indel['g_AB'] = df_Indel.apply(lambda row: 1 - row['g_AB2'] if row['g_AB2'] >= 0.5 else row['g_AB2'], axis=1)

# %%
print("SNP training set : %i (total) = %i (positive) + %i (negative)" % (df_SNP.count()[0], df_SNP[df_SNP['TP']=='Positive'].count()[0], df_SNP[df_SNP['TP']=='Negative'].count()[0]))
print("Indel training set : %i (total) = %i (positive) + %i (negative)" % (df_Indel.count()[0], df_Indel[df_Indel['TP']=='Positive'].count()[0], df_Indel[df_Indel['TP']=='Negative'].count()[0]))
# Out:
# SNP training set : 234470 (total) = 232682 (positive) + 1788 (negative)
# Indel training set : 22662 (total) = 21748 (positive) + 914 (negative)

# %%
df_SNP.head(5)
# Out:
#             variant Role    Fam        TP  va_QUAL  va_AN  va_BaseQRankSum  \
# 0  10:100009409:A:G    p  TWGS4  Positive   1002.2     54            0.921
# 1  10:100009409:A:G   mo  TWGS4  Positive   1002.2     54            0.921
# 2  10:100019115:A:G    p  TWGS4  Positive    977.2     54            1.140
# 3  10:100019115:A:G   mo  TWGS4  Positive    977.2     54            1.140
# 4  10:100152115:A:G    p  TWGS3  Positive    819.2     54            0.000
#
#    va_DP  va_ExcessHet  va_FS  ...  va_QD  va_ReadPosRankSum  va_SOR  \
# 0    900         3.093  5.083  ...  13.36              1.560   0.267
# 1    900         3.093  5.083  ...  13.36              1.560   0.267
# 2    950         3.093  0.000  ...  11.36              0.762   0.709
# 3    950         3.093  0.000  ...  11.36              0.762   0.709
# 4    864         3.093  1.010  ...  14.12             -0.361   0.976
#
#    va_VQSLOD  va_GQM  g_GQ     g_AD  g_DP     g_AB2      g_AB
# 0      21.76  90.481    99  [26,20]    46  0.434783  0.434783
# 1      21.76  90.481    99  [13,16]    29  0.551724  0.448276
# 2      21.80  94.037    99  [32,17]    49  0.346939  0.346939
# 3      21.80  94.037    99  [17,20]    37  0.540541  0.459459
# 4      21.93  90.333    99  [14,18]    32  0.562500  0.437500
#
# [5 rows x 23 columns]

# %%
df_Indel.head(5)
# Out:
#                               variant Role    Fam        TP  va_QUAL  va_AN  \
# 0                  10:100026152:GGT:G    p  TWGS5  Positive  1737.20     54
# 1                  10:100026152:GGT:G   fa  TWGS5  Positive  1737.20     54
# 2                10:100397154:TAGAA:T    p  TWGS5  Positive  1347.20     54
# 3                10:100397154:TAGAA:T   mo  TWGS5  Positive  1347.20     54
# 4  10:100672315:T:TTCTTTCTTTCTTTCTTTC    p  TWGS8  Positive   814.24     54
#
#    va_BaseQRankSum  va_DP  va_ExcessHet  va_FS  ...  va_QD  va_ReadPosRankSum  \
# 0             1.37    923         3.093  1.741  ...  19.74              1.900
# 1             1.37    923         3.093  1.741  ...  19.74              1.900
# 2             1.21    946         3.093  8.573  ...  19.81              0.921
# 3             1.21    946         3.093  8.573  ...  19.81              0.921
# 4             0.00   1064         3.093  0.000  ...  20.36             -0.071
#
#    va_SOR  va_VQSLOD  va_GQM  g_GQ     g_AD  g_DP     g_AB2      g_AB
# 0   0.895       5.97  92.444    99  [24,21]    45  0.466667  0.466667
# 1   0.895       5.97  92.444    99  [19,24]    43  0.558140  0.441860
# 2   1.655       5.49  88.556    99  [20,18]    38  0.473684  0.473684
# 3   1.655       5.49  88.556    99  [13,17]    30  0.566667  0.433333
# 4   0.693       7.80  93.556    99   [11,8]    19  0.421053  0.421053
#
# [5 rows x 23 columns]

# %% [markdown]
# ---

# %% [markdown]
# (그림 그리기)

# %%
criteria = ['va_QUAL','va_AN','va_BaseQRankSum','va_DP','va_FS','va_MQ','va_GQM',
            'va_MQRankSum','va_QD','va_ReadPosRankSum','va_SOR','g_GQ', 'g_DP', 'g_AB']

# %%
plt.figure(figsize=[32,24])

for k,l in enumerate(criteria, 1):
    plt.subplot(4,4,k)
    sns.violinplot('TP',l, data= df_SNP)
    plt.title(l) 

plt.savefig("../../Figures/plot_PN_SNP.png", )

# %%
plt.figure(figsize=[32,24])

for k,l in enumerate(criteria, 1):
    plt.subplot(4,4,k)
    sns.violinplot('TP',l, data= df_Indel)
    plt.title(l) 

plt.savefig("../../Figures/plot_PN_Indel.png", )

# %% [markdown]
# ---

# %% [markdown]
# #### 8. (Positive, Negative set) ROCube

# %%
import os 
os.chdir('/Users/lizzychoi/rett_syndrome/scripts/rocube')

# %%
# !python rocube.py -i ../../outputs/ROCube_trainMat_rett_SNP.tsv -p yes
# Out:
# [Progress] Loaded an input data.
# [Progress] Plot the distribution of quality metrics
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# [Progress] Plotting is done
# [Progress] DataFrame is ready for analysis.
# [Progress] Start ROC for the round 1
# [Progress] ROC Round 1 training sets: Positives 116341 , Negatives 894
# [Progress] Achieved specificity 0.84787 and sensitivity 0.99004 from the quality metric va_QUAL (threshold: 214.9)
# [Progress] Achieved specificity 0.20582 and sensitivity 0.99236 from the quality metric va_AN (threshold: 50.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.18792 and sensitivity 0.99014 from the quality metric va_BaseQRankSum (threshold: -1.237)
# [Progress] Achieved specificity 0.25727 and sensitivity 0.99006 from the quality metric va_DP (threshold: 451.0)
# [Progress] Achieved specificity 0.11633 and sensitivity 0.99031 from the quality metric va_FS (threshold: -18.782)
# [Progress] Achieved specificity 0.19351 and sensitivity 0.99062 from the quality metric va_MQ (threshold: 39.87)
# [Progress] Achieved specificity 0.38814 and sensitivity 0.99002 from the quality metric va_MQRankSum (threshold: -1.152)
# [Progress] Achieved specificity 0.72148 and sensitivity 0.99003 from the quality metric va_QD (threshold: 4.67)
# [Progress] Achieved specificity 0.22819 and sensitivity 0.99041 from the quality metric va_SOR (threshold: -2.006)
# [Progress] Achieved specificity 0.45526 and sensitivity 0.99 from the quality metric va_GQM (threshold: 42.0)
# [Progress] Achieved specificity 0.66219 and sensitivity 0.99001 from the quality metric g_GQ (threshold: 67.0)
# [Progress] Achieved specificity 0.63758 and sensitivity 0.99037 from the quality metric g_AB (threshold: 0.195)
# [Progress] Achieved specificity 0.22595 and sensitivity 0.99063 from the quality metric g_DP (threshold: 10.0)
#              metric      cut     sens     spec
# 0           va_QUAL  214.900  0.99004  0.84787
# 7             va_QD    4.670  0.99003  0.72148
# 10             g_GQ   67.000  0.99001  0.66219
# 11             g_AB    0.195  0.99037  0.63758
# 9            va_GQM   42.000  0.99000  0.45526
# 6      va_MQRankSum   -1.152  0.99002  0.38814
# 3             va_DP  451.000  0.99006  0.25727
# 8            va_SOR   -2.006  0.99041  0.22819
# 12             g_DP   10.000  0.99063  0.22595
# 1             va_AN   50.000  0.99236  0.20582
# 5             va_MQ   39.870  0.99062  0.19351
# 2   va_BaseQRankSum   -1.237  0.99014  0.18792
# 4             va_FS  -18.782  0.99031  0.11633
# [Progress] Completed ROC for the round 1. The most probable metric from this round is va_QUAL
# [Progress] Round 1: sensitivity 0.99004 , specificity 0.84676
# ------------------------------
# [Progress] Start ROC for the round 2
# [Progress] ROC Round 2 training sets: Positives 115182 , Negatives 137
# [Progress] Achieved specificity 0.40146 and sensitivity 0.99206 from the quality metric va_AN (threshold: 52.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.05109 and sensitivity 0.99387 from the quality metric va_BaseQRankSum (threshold: -1.344)
# [Progress] Achieved specificity 0.36496 and sensitivity 0.99025 from the quality metric va_DP (threshold: 530.0)
# [Progress] Achieved specificity 0.0292 and sensitivity 0.99341 from the quality metric va_FS (threshold: -20.336)
# [Progress] Achieved specificity 0.34307 and sensitivity 0.99012 from the quality metric va_MQ (threshold: 41.48)
# [Progress] Achieved specificity 0.44526 and sensitivity 0.99211 from the quality metric va_MQRankSum (threshold: -1.225)
# [Progress] Achieved specificity 0.49635 and sensitivity 0.99026 from the quality metric va_QD (threshold: 6.98)
# [Progress] Achieved specificity 0.08759 and sensitivity 0.99126 from the quality metric va_SOR (threshold: -2.006)
# [Progress] Achieved specificity 0.49635 and sensitivity 0.99012 from the quality metric va_GQM (threshold: 48.0)
# [Progress] Achieved specificity 0.24818 and sensitivity 0.99182 from the quality metric g_GQ (threshold: 82.0)
# [Progress] Achieved specificity 0.50365 and sensitivity 0.99022 from the quality metric g_AB (threshold: 0.227)
# [Progress] Achieved specificity 0.18248 and sensitivity 0.99011 from the quality metric g_DP (threshold: 11.0)
#              metric      cut     sens     spec
# 10             g_AB    0.227  0.99022  0.50365
# 6             va_QD    6.980  0.99026  0.49635
# 8            va_GQM   48.000  0.99012  0.49635
# 5      va_MQRankSum   -1.225  0.99211  0.44526
# 0             va_AN   52.000  0.99206  0.40146
# 2             va_DP  530.000  0.99025  0.36496
# 4             va_MQ   41.480  0.99012  0.34307
# 9              g_GQ   82.000  0.99182  0.24818
# 11             g_DP   11.000  0.99011  0.18248
# 7            va_SOR   -2.006  0.99126  0.08759
# 1   va_BaseQRankSum   -1.344  0.99387  0.05109
# 3             va_FS  -20.336  0.99341  0.02920
# [Progress] Completed ROC for the round 2. The most probable metric from this round is g_AB
# [Progress] Round 2: sensitivity 0.98075 , specificity 0.9217
# ------------------------------
# [Progress] Start ROC for the round 3
# [Progress] ROC Round 3 training sets: Positives 114102 , Negatives 70
# [Progress] Achieved specificity 0.55714 and sensitivity 0.99377 from the quality metric va_AN (threshold: 52.0)
# [Progress] Achieved specificity 0.08571 and sensitivity 0.9543 from the quality metric va_BaseQRankSum (threshold: -0.868)
# [Progress] Achieved specificity 0.68571 and sensitivity 0.95301 from the quality metric va_DP (threshold: 707.0)
# [Progress] Achieved specificity 0.02857 and sensitivity 0.96314 from the quality metric va_FS (threshold: -12.885)
# [Progress] Achieved specificity 1.0 and sensitivity 0.95745 from the quality metric va_MQ (threshold: 57.35)
# [Progress] Achieved specificity 0.54286 and sensitivity 0.97803 from the quality metric va_MQRankSum (threshold: -0.063)
# [Progress] Achieved specificity 0.51429 and sensitivity 0.96373 from the quality metric va_QD (threshold: 9.59)
# [Progress] Achieved specificity 0.18571 and sensitivity 0.96014 from the quality metric va_SOR (threshold: -1.536)
# [Progress] Achieved specificity 0.85714 and sensitivity 0.95789 from the quality metric va_GQM (threshold: 71.0)
# [Progress] Achieved specificity 0.12857 and sensitivity 0.9956 from the quality metric g_GQ (threshold: 82.0)
# [Progress] Achieved specificity 0.64286 and sensitivity 0.9567 from the quality metric g_DP (threshold: 17.0)
#              metric      cut     sens     spec
# 4             va_MQ   57.350  0.95745  1.00000
# 8            va_GQM   71.000  0.95789  0.85714
# 2             va_DP  707.000  0.95301  0.68571
# 10             g_DP   17.000  0.95670  0.64286
# 0             va_AN   52.000  0.99377  0.55714
# 5      va_MQRankSum   -0.063  0.97803  0.54286
# 6             va_QD    9.590  0.96373  0.51429
# 7            va_SOR   -1.536  0.96014  0.18571
# 9              g_GQ   82.000  0.99560  0.12857
# 1   va_BaseQRankSum   -0.868  0.95430  0.08571
# 3             va_FS  -12.885  0.96314  0.02857
# [Progress] Completed ROC for the round 3. The most probable metric from this round is va_MQ
# [Progress] Round 3: sensitivity 0.93908 , specificity 0.99888
# ------------------------------
# [Done] Completed ROC analysis

# %%
# !python rocube.py -i ../../outputs/ROCube_trainMat_rett_Indel.tsv -p yes
# Out:
# [Progress] Loaded an input data.
# [Progress] Plot the distribution of quality metrics
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# [Progress] Plotting is done
# [Progress] DataFrame is ready for analysis.
# [Progress] Start ROC for the round 1
# [Progress] ROC Round 1 training sets: Positives 10874 , Negatives 457
# [Progress] Achieved specificity 0.26477 and sensitivity 0.99522 from the quality metric va_QUAL (threshold: 65.78)
# [Progress] Achieved specificity 0.07877 and sensitivity 0.99522 from the quality metric va_AN (threshold: 32.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.05033 and sensitivity 0.99531 from the quality metric va_BaseQRankSum (threshold: -1.508)
# [Progress] Achieved specificity 0.1488 and sensitivity 0.99522 from the quality metric va_DP (threshold: 94.0)
# [Progress] Achieved specificity 0.09847 and sensitivity 0.99522 from the quality metric va_FS (threshold: -23.814)
# [Progress] Achieved specificity 0.14661 and sensitivity 0.99503 from the quality metric va_MQ (threshold: 26.57)
# [Progress] Achieved specificity 0.10722 and sensitivity 0.99503 from the quality metric va_MQRankSum (threshold: -2.697)
# [Progress] Achieved specificity 0.18162 and sensitivity 0.99522 from the quality metric va_QD (threshold: 1.42)
# [Progress] Achieved specificity 0.2035 and sensitivity 0.99503 from the quality metric va_SOR (threshold: -3.056)
# [Progress] Achieved specificity 0.1488 and sensitivity 0.99605 from the quality metric va_GQM (threshold: 14.0)
# [Progress] Achieved specificity 0.14004 and sensitivity 0.99549 from the quality metric g_GQ (threshold: 23.0)
# [Progress] Achieved specificity 0.14004 and sensitivity 0.99522 from the quality metric g_AB (threshold: 0.094)
# [Progress] Achieved specificity 0.13567 and sensitivity 0.9954 from the quality metric g_DP (threshold: 4.0)
#              metric     cut     sens     spec
# 0           va_QUAL  65.780  0.99522  0.26477
# 8            va_SOR  -3.056  0.99503  0.20350
# 7             va_QD   1.420  0.99522  0.18162
# 3             va_DP  94.000  0.99522  0.14880
# 9            va_GQM  14.000  0.99605  0.14880
# 5             va_MQ  26.570  0.99503  0.14661
# 10             g_GQ  23.000  0.99549  0.14004
# 11             g_AB   0.094  0.99522  0.14004
# 12             g_DP   4.000  0.99540  0.13567
# 6      va_MQRankSum  -2.697  0.99503  0.10722
# 4             va_FS -23.814  0.99522  0.09847
# 1             va_AN  32.000  0.99522  0.07877
# 2   va_BaseQRankSum  -1.508  0.99531  0.05033
# [Progress] Completed ROC for the round 1. The most probable metric from this round is va_QUAL
# [Progress] Round 1: sensitivity 0.99531 , specificity 0.26477
# ------------------------------
# [Progress] Start ROC for the round 2
# [Progress] ROC Round 2 training sets: Positives 10823 , Negatives 336
# [Progress] Achieved specificity 0.10119 and sensitivity 0.99538 from the quality metric va_AN (threshold: 32.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.04762 and sensitivity 0.99538 from the quality metric va_BaseQRankSum (threshold: -1.508)
# [Progress] Achieved specificity 0.19345 and sensitivity 0.9952 from the quality metric va_DP (threshold: 96.0)
# [Progress] Achieved specificity 0.08631 and sensitivity 0.9952 from the quality metric va_FS (threshold: -23.814)
# [Progress] Achieved specificity 0.16964 and sensitivity 0.99501 from the quality metric va_MQ (threshold: 26.81)
# [Progress] Achieved specificity 0.1131 and sensitivity 0.9952 from the quality metric va_MQRankSum (threshold: -2.697)
# [Progress] Achieved specificity 0.17262 and sensitivity 0.99501 from the quality metric va_QD (threshold: 2.13)
# [Progress] Achieved specificity 0.20536 and sensitivity 0.99501 from the quality metric va_SOR (threshold: -2.964)
# [Progress] Achieved specificity 0.19048 and sensitivity 0.99529 from the quality metric va_GQM (threshold: 15.0)
# [Progress] Achieved specificity 0.09821 and sensitivity 0.99538 from the quality metric g_GQ (threshold: 26.0)
# [Progress] Achieved specificity 0.12202 and sensitivity 0.99529 from the quality metric g_AB (threshold: 0.1)
# [Progress] Achieved specificity 0.14286 and sensitivity 0.99584 from the quality metric g_DP (threshold: 4.0)
#              metric     cut     sens     spec
# 7            va_SOR  -2.964  0.99501  0.20536
# 2             va_DP  96.000  0.99520  0.19345
# 8            va_GQM  15.000  0.99529  0.19048
# 6             va_QD   2.130  0.99501  0.17262
# 4             va_MQ  26.810  0.99501  0.16964
# 11             g_DP   4.000  0.99584  0.14286
# 10             g_AB   0.100  0.99529  0.12202
# 5      va_MQRankSum  -2.697  0.99520  0.11310
# 0             va_AN  32.000  0.99538  0.10119
# 9              g_GQ  26.000  0.99538  0.09821
# 3             va_FS -23.814  0.99520  0.08631
# 1   va_BaseQRankSum  -1.508  0.99538  0.04762
# [Progress] Completed ROC for the round 2. The most probable metric from this round is va_SOR
# [Progress] Round 2: sensitivity 0.99034 , specificity 0.41138
# ------------------------------
# [Progress] Start ROC for the round 3
# [Progress] ROC Round 3 training sets: Positives 10769 , Negatives 269
# [Progress] Achieved specificity 0.08922 and sensitivity 0.99545 from the quality metric va_AN (threshold: 32.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.03346 and sensitivity 0.99545 from the quality metric va_BaseQRankSum (threshold: -1.501)
# [Progress] Achieved specificity 0.2119 and sensitivity 0.99508 from the quality metric va_DP (threshold: 101.0)
# [Progress] Achieved specificity 0.03346 and sensitivity 0.99629 from the quality metric va_FS (threshold: -23.033)
# [Progress] Achieved specificity 0.18587 and sensitivity 0.99508 from the quality metric va_MQ (threshold: 26.87)
# [Progress] Achieved specificity 0.11152 and sensitivity 0.99526 from the quality metric va_MQRankSum (threshold: -2.43)
# [Progress] Achieved specificity 0.19703 and sensitivity 0.99517 from the quality metric va_QD (threshold: 2.31)
# [Progress] Achieved specificity 0.18216 and sensitivity 0.99545 from the quality metric va_GQM (threshold: 15.0)
# [Progress] Achieved specificity 0.11896 and sensitivity 0.99508 from the quality metric g_GQ (threshold: 28.0)
# [Progress] Achieved specificity 0.13383 and sensitivity 0.99508 from the quality metric g_AB (threshold: 0.11)
# [Progress] Achieved specificity 0.1487 and sensitivity 0.99629 from the quality metric g_DP (threshold: 4.0)
#              metric      cut     sens     spec
# 2             va_DP  101.000  0.99508  0.21190
# 6             va_QD    2.310  0.99517  0.19703
# 4             va_MQ   26.870  0.99508  0.18587
# 7            va_GQM   15.000  0.99545  0.18216
# 10             g_DP    4.000  0.99629  0.14870
# 9              g_AB    0.110  0.99508  0.13383
# 8              g_GQ   28.000  0.99508  0.11896
# 5      va_MQRankSum   -2.430  0.99526  0.11152
# 0             va_AN   32.000  0.99545  0.08922
# 1   va_BaseQRankSum   -1.501  0.99545  0.03346
# 3             va_FS  -23.033  0.99629  0.03346
# [Progress] Completed ROC for the round 3. The most probable metric from this round is va_DP
# [Progress] Round 3: sensitivity 0.98547 , specificity 0.52954
# ------------------------------
# [Progress] Start ROC for the round 4
# [Progress] ROC Round 4 training sets: Positives 10716 , Negatives 215
# [Progress] Achieved specificity 0.05581 and sensitivity 0.99589 from the quality metric va_AN (threshold: 42.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.04186 and sensitivity 0.99543 from the quality metric va_BaseQRankSum (threshold: -1.501)
# [Progress] Achieved specificity 0.04186 and sensitivity 0.99627 from the quality metric va_FS (threshold: -23.033)
# [Progress] Achieved specificity 0.19535 and sensitivity 0.99515 from the quality metric va_MQ (threshold: 27.41)
# [Progress] Achieved specificity 0.13953 and sensitivity 0.99524 from the quality metric va_MQRankSum (threshold: -2.43)
# [Progress] Achieved specificity 0.24651 and sensitivity 0.99515 from the quality metric va_QD (threshold: 2.33)
# [Progress] Achieved specificity 0.11163 and sensitivity 0.99533 from the quality metric va_GQM (threshold: 18.0)
# [Progress] Achieved specificity 0.14419 and sensitivity 0.99505 from the quality metric g_GQ (threshold: 30.0)
# [Progress] Achieved specificity 0.16279 and sensitivity 0.99505 from the quality metric g_AB (threshold: 0.11)
# [Progress] Achieved specificity 0.07907 and sensitivity 0.99748 from the quality metric g_DP (threshold: 4.0)
#             metric     cut     sens     spec
# 5            va_QD   2.330  0.99515  0.24651
# 3            va_MQ  27.410  0.99515  0.19535
# 8             g_AB   0.110  0.99505  0.16279
# 7             g_GQ  30.000  0.99505  0.14419
# 4     va_MQRankSum  -2.430  0.99524  0.13953
# 6           va_GQM  18.000  0.99533  0.11163
# 9             g_DP   4.000  0.99748  0.07907
# 0            va_AN  42.000  0.99589  0.05581
# 1  va_BaseQRankSum  -1.501  0.99543  0.04186
# 2            va_FS -23.033  0.99627  0.04186
# [Progress] Completed ROC for the round 4. The most probable metric from this round is va_QD
# [Progress] Round 4: sensitivity 0.98078 , specificity 0.64551
# ------------------------------
# [Progress] Start ROC for the round 5
# [Progress] ROC Round 5 training sets: Positives 10665 , Negatives 162
# [Progress] Achieved specificity 0.07407 and sensitivity 0.99616 from the quality metric va_AN (threshold: 42.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.03086 and sensitivity 0.9955 from the quality metric va_BaseQRankSum (threshold: -1.501)
# [Progress] Achieved specificity 0.04321 and sensitivity 0.99644 from the quality metric va_FS (threshold: -23.121)
# [Progress] Achieved specificity 0.24691 and sensitivity 0.99512 from the quality metric va_MQ (threshold: 27.96)
# [Progress] Achieved specificity 0.10494 and sensitivity 0.99503 from the quality metric va_MQRankSum (threshold: -2.35)
# [Progress] Achieved specificity 0.14198 and sensitivity 0.99531 from the quality metric va_GQM (threshold: 18.0)
# [Progress] Achieved specificity 0.16049 and sensitivity 0.99503 from the quality metric g_GQ (threshold: 33.0)
# [Progress] Achieved specificity 0.16049 and sensitivity 0.99503 from the quality metric g_AB (threshold: 0.125)
# [Progress] Achieved specificity 0.09877 and sensitivity 0.99747 from the quality metric g_DP (threshold: 4.0)
#             metric     cut     sens     spec
# 3            va_MQ  27.960  0.99512  0.24691
# 6             g_GQ  33.000  0.99503  0.16049
# 7             g_AB   0.125  0.99503  0.16049
# 5           va_GQM  18.000  0.99531  0.14198
# 4     va_MQRankSum  -2.350  0.99503  0.10494
# 8             g_DP   4.000  0.99747  0.09877
# 0            va_AN  42.000  0.99616  0.07407
# 2            va_FS -23.121  0.99644  0.04321
# 1  va_BaseQRankSum  -1.501  0.99550  0.03086
# [Progress] Completed ROC for the round 5. The most probable metric from this round is va_MQ
# [Progress] Round 5: sensitivity 0.976 , specificity 0.73085
# ------------------------------
# [Progress] Start ROC for the round 6
# [Progress] ROC Round 6 training sets: Positives 10613 , Negatives 123
# [Progress] Achieved specificity 0.11382 and sensitivity 0.99519 from the quality metric va_AN (threshold: 44.0)
# /Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:445: RuntimeWarning: invalid value encountered in greater
#   data = list(data)
# [Progress] Achieved specificity 0.04065 and sensitivity 0.99548 from the quality metric va_BaseQRankSum (threshold: -1.501)
# [Progress] Achieved specificity 0.05691 and sensitivity 0.99642 from the quality metric va_FS (threshold: -23.121)
# [Progress] Achieved specificity 0.13821 and sensitivity 0.99501 from the quality metric va_MQRankSum (threshold: -2.35)
# [Progress] Achieved specificity 0.1626 and sensitivity 0.99529 from the quality metric va_GQM (threshold: 19.0)
# [Progress] Achieved specificity 0.17886 and sensitivity 0.99529 from the quality metric g_GQ (threshold: 33.0)
# [Progress] Achieved specificity 0.18699 and sensitivity 0.9951 from the quality metric g_AB (threshold: 0.129)
# [Progress] Achieved specificity 0.13821 and sensitivity 0.99576 from the quality metric g_DP (threshold: 5.0)
#             metric     cut     sens     spec
# 6             g_AB   0.129  0.99510  0.18699
# 5             g_GQ  33.000  0.99529  0.17886
# 4           va_GQM  19.000  0.99529  0.16260
# 3     va_MQRankSum  -2.350  0.99501  0.13821
# 7             g_DP   5.000  0.99576  0.13821
# 0            va_AN  44.000  0.99519  0.11382
# 2            va_FS -23.121  0.99642  0.05691
# 1  va_BaseQRankSum  -1.501  0.99548  0.04065
# [Progress] Completed ROC for the round 6. The most probable metric from this round is g_AB
# [Progress] Round 6: sensitivity 0.97131 , specificity 0.78118
# ------------------------------
# [Progress] Start ROC for the round 7
# [Progress] ROC Round 7 training sets: Positives 10562 , Negatives 100
# [Progress] Achieved specificity 0.24 and sensitivity 0.99318 from the quality metric va_AN (threshold: 48.0)
# [Progress] Achieved specificity 0.07 and sensitivity 0.99195 from the quality metric va_BaseQRankSum (threshold: -1.26)
# [Progress] Achieved specificity 0.05 and sensitivity 0.9929 from the quality metric va_FS (threshold: -20.213)
# [Progress] Achieved specificity 0.14 and sensitivity 0.99091 from the quality metric va_MQRankSum (threshold: -1.674)
# [Progress] Achieved specificity 0.33 and sensitivity 0.99034 from the quality metric va_GQM (threshold: 25.0)
# [Progress] Achieved specificity 0.29 and sensitivity 0.99138 from the quality metric g_GQ (threshold: 58.0)
# [Progress] Achieved specificity 0.31 and sensitivity 0.99186 from the quality metric g_DP (threshold: 7.0)
#             metric     cut     sens  spec
# 4           va_GQM  25.000  0.99034  0.33
# 6             g_DP   7.000  0.99186  0.31
# 5             g_GQ  58.000  0.99138  0.29
# 0            va_AN  48.000  0.99318  0.24
# 3     va_MQRankSum  -1.674  0.99091  0.14
# 1  va_BaseQRankSum  -1.260  0.99195  0.07
# 2            va_FS -20.213  0.99290  0.05
# [Progress] Completed ROC for the round 7. The most probable metric from this round is va_GQM
# [Progress] Round 7: sensitivity 0.96285 , specificity 0.8512
# ------------------------------
# [Progress] Start ROC for the round 8
# [Progress] ROC Round 8 training sets: Positives 10470 , Negatives 68
# [Progress] Achieved specificity 0.23529 and sensitivity 0.99351 from the quality metric va_AN (threshold: 50.0)
# [Progress] Achieved specificity 0.08824 and sensitivity 0.99198 from the quality metric va_BaseQRankSum (threshold: -1.26)
# [Progress] Achieved specificity 0.05882 and sensitivity 0.99312 from the quality metric va_FS (threshold: -20.27)
# [Progress] Achieved specificity 0.19118 and sensitivity 0.99083 from the quality metric va_MQRankSum (threshold: -1.674)
# [Progress] Achieved specificity 0.20588 and sensitivity 0.9915 from the quality metric g_GQ (threshold: 63.0)
# [Progress] Achieved specificity 0.22059 and sensitivity 0.99179 from the quality metric g_DP (threshold: 8.0)
#             metric     cut     sens     spec
# 0            va_AN  50.000  0.99351  0.23529
# 5             g_DP   8.000  0.99179  0.22059
# 4             g_GQ  63.000  0.99150  0.20588
# 3     va_MQRankSum  -1.674  0.99083  0.19118
# 1  va_BaseQRankSum  -1.260  0.99198  0.08824
# 2            va_FS -20.270  0.99312  0.05882
# [Progress] Completed ROC for the round 8. The most probable metric from this round is va_AN
# [Progress] Round 8: sensitivity 0.95843 , specificity 0.86871
# ------------------------------
# [Progress] Start ROC for the round 9
# [Progress] ROC Round 9 training sets: Positives 10422 , Negatives 60
# [Progress] Achieved specificity 0.1 and sensitivity 0.99213 from the quality metric va_BaseQRankSum (threshold: -1.26)
# [Progress] Achieved specificity 0.03333 and sensitivity 0.99933 from the quality metric va_FS (threshold: -32.343)
# [Progress] Achieved specificity 0.21667 and sensitivity 0.99079 from the quality metric va_MQRankSum (threshold: -1.674)
# [Progress] Achieved specificity 0.28333 and sensitivity 0.99079 from the quality metric g_GQ (threshold: 69.0)
# [Progress] Achieved specificity 0.21667 and sensitivity 0.9929 from the quality metric g_DP (threshold: 8.0)
#             metric     cut     sens     spec
# 3             g_GQ  69.000  0.99079  0.28333
# 2     va_MQRankSum  -1.674  0.99079  0.21667
# 4             g_DP   8.000  0.99290  0.21667
# 0  va_BaseQRankSum  -1.260  0.99213  0.10000
# 1            va_FS -32.343  0.99933  0.03333
# [Progress] Completed ROC for the round 9. The most probable metric from this round is g_GQ
# [Progress] Round 9: sensitivity 0.94988 , specificity 0.89278
# ------------------------------
# [Progress] Start ROC for the round 10
# [Progress] ROC Round 10 training sets: Positives 10329 , Negatives 49
# [Progress] Achieved specificity 0.06122 and sensitivity 0.99274 from the quality metric va_BaseQRankSum (threshold: -1.27)
# [Progress] Achieved specificity 0.02041 and sensitivity 1.0 from the quality metric va_FS (threshold: -100.21)
# [Progress] Achieved specificity 0.26531 and sensitivity 0.99071 from the quality metric va_MQRankSum (threshold: -1.674)
# [Progress] Achieved specificity 0.20408 and sensitivity 0.99574 from the quality metric g_DP (threshold: 8.0)
#             metric      cut     sens     spec
# 2     va_MQRankSum   -1.674  0.99071  0.26531
# 3             g_DP    8.000  0.99574  0.20408
# 0  va_BaseQRankSum   -1.270  0.99274  0.06122
# 1            va_FS -100.210  1.00000  0.02041
# [Progress] Completed ROC for the round 10. The most probable metric from this round is va_MQRankSum
# [Progress] Round 10: sensitivity 0.94105 , specificity 0.91904
# ------------------------------
# [Progress] Start ROC for the round 11
# [Progress] ROC Round 11 training sets: Positives 10233 , Negatives 37
# [Progress] Achieved specificity 0.02703 and sensitivity 0.99482 from the quality metric va_BaseQRankSum (threshold: -1.383)
# [Progress] Achieved specificity 0.02703 and sensitivity 1.0 from the quality metric va_FS (threshold: -100.21)
# [Progress] Achieved specificity 0.27027 and sensitivity 0.9958 from the quality metric g_DP (threshold: 8.0)
#             metric      cut     sens     spec
# 2             g_DP    8.000  0.99580  0.27027
# 0  va_BaseQRankSum   -1.383  0.99482  0.02703
# 1            va_FS -100.210  1.00000  0.02703
# [Progress] Completed ROC for the round 11. The most probable metric from this round is g_DP
# [Progress] Round 11: sensitivity 0.93875 , specificity 0.93873
# ------------------------------
# [Progress] Start ROC for the round 12
# [Progress] ROC Round 12 training sets: Positives 10208 , Negatives 28
# [Progress] Achieved specificity 0.0 and sensitivity 0.9999 from the quality metric va_BaseQRankSum (threshold: -2.799)
# [Progress] Achieved specificity 0.03571 and sensitivity 1.0 from the quality metric va_FS (threshold: -100.21)
#             metric      cut    sens     spec
# 1            va_FS -100.210  1.0000  0.03571
# 0  va_BaseQRankSum   -2.799  0.9999  0.00000
# [Progress] Completed ROC for the round 12. The most probable metric from this round is va_FS
# [Progress] Round 12: sensitivity 0.93875 , specificity 0.93873
# ------------------------------
# [Progress] Start ROC for the round 13
# [Progress] ROC Round 13 training sets: Positives 10208 , Negatives 28
# [Progress] Achieved specificity 0.0 and sensitivity 0.9999 from the quality metric va_BaseQRankSum (threshold: -2.799)
#             metric    cut    sens  spec
# 0  va_BaseQRankSum -2.799  0.9999   0.0
# [Progress] Completed ROC for the round 13. The most probable metric from this round is va_BaseQRankSum
# [Progress] Round 13: sensitivity 0.93875 , specificity 0.93873
# ------------------------------
# [Progress] Start ROC for the round 14
# [Progress] ROC Round 14 training sets: Positives 10208 , Negatives 28
# Traceback (most recent call last):
#   File "rocube.py", line 184, in <module>
#     main(args.infile, args.number_threads, args.output_tag, args.min_sens, args.min_spec, args.plot)
#   File "rocube.py", line 134, in main
#     print(res_round.sort_values('spec', ascending=False))
#   File "/Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 4993, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "/Users/lizzychoi/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py", line 1774, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 'spec'

# %% [markdown]
# ---

# %% [markdown]
# ##### discussion
# (2019.11.29)
# - ~(info에)`va_HaplotypeScore`, `va_MQ0`, `va_GQM`이 없어서 0으로 둠~
#
# ---
# (2019.12.5)
# - variant filtering 추가 ((1)`Filter == pass`, (2)gnomAD에 AF 정보 없는 variant) : ~*생각보다 여전히 training set의 크기가 크다*~
# - 그래프 추가(positive set vs. negative set)
# - **rocube** : ~기준(`'va_QUAL','va_AN','va_DP','va_MQ','va_QD','g_AB','g_DP'`)만 사용해서 돌려본 결과~

# %% [markdown]
# ---

# %% [markdown]
# (2019. 12. 9)

# %% [markdown]
# - gnomAD AC==0만 포함 : 'VEP annotation 결과사용'한 경우와 'gnomAD VCF을 사용'한 경우 차이가 난다. => *우선은 'VEP annotation'결과만 사용*
#     - **branch** 새로 만들어서 'gnomAD VCF을 사용'한 경우해보자
# - 그래프 기준 추가 : **g_GQ**~(variant qc이후 gq mean 사용)~, **g_DP**(그래프 그릴때 계산), **g_AB**(그래프 그릴때 계산)

# %% [markdown]
# ---

# %% [markdown]
# (2019. 12. 13)
#
# - autosomal contigs만 남김(즉, X, Y, and MT 모두 제외)
# - (training set)`va_HaplotypeScore`, `va_MQ0` 제외, **`va_GQM`**은 `variant_qc.gq_stats.mean`으로(2019.11.29 수정)
# - rocube
#     - `va_ExcessHet`, `va_InbreedingCoeff`, `va_VQSLOD`는 왜 안 쓰는지
#     - Indel에서는 `va_ReadPosRankSum`제외하고 실행

# %% [markdown]
# (2019.12.17)
# - False positive 기준 수정 : 하나는 **무조건 자손**에게서 발견되어야한다.(수정 완료)--> negative 수가 많이 줄음

# %% [markdown]
# (2019.12.23)
# - False positive 기준 수정: 다른 하나는 **부모**에게서 발견되어야한다. --> negative 수 더 줄음
